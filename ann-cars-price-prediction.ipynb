# %% [markdown]
# # Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('/kaggle/input/ann-car-sales-price-prediction/car_purchasing.csv', encoding='ISO-8859-1')
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %%
df.head()
# Out:
#          age  annual Salary  credit card debt    net worth  \
# 0  41.851720    62812.09301      11609.380910  238961.2505
# 1  40.870623    66646.89292       9572.957136  530973.9078
# 2  43.152897    53798.55112      11160.355060  638467.1773
# 3  58.271369    79370.03798      14426.164850  548599.0524
# 4  57.313749    59729.15130       5358.712177  560304.0671
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  500 non-null    float64
#  1   annual Salary        500 non-null    float64
#  2   credit card debt     500 non-null    float64
#  3   net worth            500 non-null    float64
#  4   car purchase amount  500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
plt.scatter(df['annual Salary'] , df['credit card debt'])
plt.xlabel('annual Salary')
plt.ylabel('credit card debt')
plt.title('the corr between credit card debt and annual Salary')
# Out:
# Text(0.5, 1.0, 'the corr between credit card debt and annual Salary')

# %%
sns.pairplot(df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %% [markdown]
# # Preprocessing

# %%
scale = MinMaxScaler()
X = scale.fit_transform(X)
y = scale.fit_transform(y.values.reshape(-1, 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %% [markdown]
# # Linear regrssion

# %%
#Trying linear regression
lreg = LinearRegression()
lreg.fit(X_train, y_train)
print('Train score', lreg.score(X_train, y_train))
print('Test score', lreg.score(X_test, y_test))
# Out:
# Train score 0.9999999829649089
# Test score 0.9999999707169606

# %%
y_pred = lreg.predict(X_test)

# %% [markdown]
# # ANN Model

# %%
ann = Sequential([Dense(32, activation="relu"),
                 Dense(1, activation='linear')])

ann.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['mean_absolute_error'])


history = ann.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 22ms/step - loss: 0.3854 - mean_absolute_error: 0.5803 - val_loss: 0.3078 - val_mean_absolute_error: 0.5198
# Epoch 2/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2614 - mean_absolute_error: 0.4661 - val_loss: 0.2000 - val_mean_absolute_error: 0.4105
# Epoch 3/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1705 - mean_absolute_error: 0.3638 - val_loss: 0.1238 - val_mean_absolute_error: 0.3109
# Epoch 4/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1070 - mean_absolute_error: 0.2730 - val_loss: 0.0742 - val_mean_absolute_error: 0.2265
# Epoch 5/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0683 - mean_absolute_error: 0.2081 - val_loss: 0.0455 - val_mean_absolute_error: 0.1695
# Epoch 6/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0472 - mean_absolute_error: 0.1703 - val_loss: 0.0326 - val_mean_absolute_error: 0.1410
# Epoch 7/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0381 - mean_absolute_error: 0.1563 - val_loss: 0.0281 - val_mean_absolute_error: 0.1291
# Epoch 8/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0345 - mean_absolute_error: 0.1512 - val_loss: 0.0259 - val_mean_absolute_error: 0.1251
# Epoch 9/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0320 - mean_absolute_error: 0.1458 - val_loss: 0.0234 - val_mean_absolute_error: 0.1196
# Epoch 10/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0287 - mean_absolute_error: 0.1374 - val_loss: 0.0208 - val_mean_absolute_error: 0.1116
# Epoch 11/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0255 - mean_absolute_error: 0.1281 - val_loss: 0.0183 - val_mean_absolute_error: 0.1045
# Epoch 12/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0225 - mean_absolute_error: 0.1191 - val_loss: 0.0166 - val_mean_absolute_error: 0.0999
# Epoch 13/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0201 - mean_absolute_error: 0.1121 - val_loss: 0.0150 - val_mean_absolute_error: 0.0952
# Epoch 14/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0180 - mean_absolute_error: 0.1059 - val_loss: 0.0136 - val_mean_absolute_error: 0.0906
# Epoch 15/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0162 - mean_absolute_error: 0.1005 - val_loss: 0.0123 - val_mean_absolute_error: 0.0862
# Epoch 16/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0147 - mean_absolute_error: 0.0954 - val_loss: 0.0112 - val_mean_absolute_error: 0.0819
# Epoch 17/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0133 - mean_absolute_error: 0.0907 - val_loss: 0.0101 - val_mean_absolute_error: 0.0778
# Epoch 18/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0120 - mean_absolute_error: 0.0864 - val_loss: 0.0093 - val_mean_absolute_error: 0.0741
# Epoch 19/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0109 - mean_absolute_error: 0.0823 - val_loss: 0.0085 - val_mean_absolute_error: 0.0706
# Epoch 20/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0099 - mean_absolute_error: 0.0783 - val_loss: 0.0078 - val_mean_absolute_error: 0.0673
# Epoch 21/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0091 - mean_absolute_error: 0.0750 - val_loss: 0.0072 - val_mean_absolute_error: 0.0644
# Epoch 22/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0083 - mean_absolute_error: 0.0719 - val_loss: 0.0066 - val_mean_absolute_error: 0.0618
# Epoch 23/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0076 - mean_absolute_error: 0.0686 - val_loss: 0.0061 - val_mean_absolute_error: 0.0593
# Epoch 24/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0070 - mean_absolute_error: 0.0658 - val_loss: 0.0057 - val_mean_absolute_error: 0.0571
# Epoch 25/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0065 - mean_absolute_error: 0.0634 - val_loss: 0.0053 - val_mean_absolute_error: 0.0551
# Epoch 26/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0060 - mean_absolute_error: 0.0610 - val_loss: 0.0049 - val_mean_absolute_error: 0.0532
# Epoch 27/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0056 - mean_absolute_error: 0.0590 - val_loss: 0.0046 - val_mean_absolute_error: 0.0516
# Epoch 28/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0052 - mean_absolute_error: 0.0568 - val_loss: 0.0044 - val_mean_absolute_error: 0.0502
# Epoch 29/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0049 - mean_absolute_error: 0.0551 - val_loss: 0.0041 - val_mean_absolute_error: 0.0485
# Epoch 30/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0046 - mean_absolute_error: 0.0534 - val_loss: 0.0039 - val_mean_absolute_error: 0.0475
# Epoch 31/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0043 - mean_absolute_error: 0.0520 - val_loss: 0.0037 - val_mean_absolute_error: 0.0470
# Epoch 32/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0041 - mean_absolute_error: 0.0505 - val_loss: 0.0035 - val_mean_absolute_error: 0.0459
# Epoch 33/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0039 - mean_absolute_error: 0.0492 - val_loss: 0.0033 - val_mean_absolute_error: 0.0448
# Epoch 34/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0037 - mean_absolute_error: 0.0479 - val_loss: 0.0032 - val_mean_absolute_error: 0.0441
# Epoch 35/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0035 - mean_absolute_error: 0.0468 - val_loss: 0.0030 - val_mean_absolute_error: 0.0434
# Epoch 36/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0034 - mean_absolute_error: 0.0456 - val_loss: 0.0029 - val_mean_absolute_error: 0.0420
# Epoch 37/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0032 - mean_absolute_error: 0.0444 - val_loss: 0.0027 - val_mean_absolute_error: 0.0416
# Epoch 38/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0030 - mean_absolute_error: 0.0435 - val_loss: 0.0026 - val_mean_absolute_error: 0.0404
# Epoch 39/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0423 - val_loss: 0.0025 - val_mean_absolute_error: 0.0396
# Epoch 40/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0414 - val_loss: 0.0024 - val_mean_absolute_error: 0.0386
# Epoch 41/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0404 - val_loss: 0.0022 - val_mean_absolute_error: 0.0383
# Epoch 42/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0391 - val_loss: 0.0021 - val_mean_absolute_error: 0.0369
# Epoch 43/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0024 - mean_absolute_error: 0.0387 - val_loss: 0.0020 - val_mean_absolute_error: 0.0359
# Epoch 44/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0373 - val_loss: 0.0019 - val_mean_absolute_error: 0.0356
# Epoch 45/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0021 - mean_absolute_error: 0.0364 - val_loss: 0.0018 - val_mean_absolute_error: 0.0344
# Epoch 46/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0020 - mean_absolute_error: 0.0356 - val_loss: 0.0017 - val_mean_absolute_error: 0.0332
# Epoch 47/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0019 - mean_absolute_error: 0.0346 - val_loss: 0.0016 - val_mean_absolute_error: 0.0327
# Epoch 48/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0336 - val_loss: 0.0015 - val_mean_absolute_error: 0.0319
# Epoch 49/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0327 - val_loss: 0.0014 - val_mean_absolute_error: 0.0306
# Epoch 50/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0320 - val_loss: 0.0014 - val_mean_absolute_error: 0.0302

# %%
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmin(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
ann_y_pred = ann.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
r2 = r2_score(y_test, y_pred)
print('R2 score:', r2)
# Out:
# R2 score: 0.9999999707169606

# %%
ann.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0295
# [0.0015479379799216986, 0.029516177251935005]

# %%
ann.predict([[40, 70000.500, 9550,534000]])
# Out:
# 1/1 [==============================] - 0s 38ms/step
# array([[50879.48]], dtype=float32)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, label='Linear Regression')
plt.scatter(y_test, ann_y_pred, label='ANN')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='gray')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.legend()
plt.show()
